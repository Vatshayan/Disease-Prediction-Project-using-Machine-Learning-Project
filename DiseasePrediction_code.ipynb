# %% [markdown]
# **DISEASE PREDICTION PROJECT**

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2f3735b9-e170-46c0-a87b-29c5d14c6e6d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2f3735b9-e170-46c0-a87b-29c5d14c6e6d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Testing.csv to Testing.csv
# Saving Training.csv to Training.csv

# %%
# Load Training data
df = pd.read_csv('Training.csv')

df.head()
# Out:
#    itching  skin_rash  ...  yellow_crust_ooze         prognosis
# 0        1          1  ...                  0  Fungal infection
# 1        0          1  ...                  0  Fungal infection
# 2        1          0  ...                  0  Fungal infection
# 3        1          1  ...                  0  Fungal infection
# 4        1          1  ...                  0  Fungal infection
#
# [5 rows x 133 columns]

# %%
df.tail()
# Out:
#       itching  ...                                prognosis
# 4915        0  ...  (vertigo) Paroymsal  Positional Vertigo
# 4916        0  ...                                     Acne
# 4917        0  ...                  Urinary tract infection
# 4918        0  ...                                Psoriasis
# 4919        0  ...                                 Impetigo
#
# [5 rows x 133 columns]

# %% [markdown]
# WAIT WAIT WAIT :)
#
#
#
#
#
#
# There is more numbers of line of code...
# But for only students and startups........
#
# If you need then please mail me now at **vatshayan007@gmail.com** to get detailed Project code, Project report, synopsis, PPT and Research paper on this Project.
#
# Ask freely!
